# %% [markdown]
# ## Dimensions
# 1. Number of clusters (3,5,7,9)
# 2. Cluster validity index (DBIndex, Silhoutte Index, Dunn Index)
# 3. Algorithms (Genetic, Particle Swarm, Particle Gray Wolf)
# 4. Datasets (BBC, BBC Sports, Reuters, 20 newsgroup, etc.)

# %%
import nltk
import os
import re
import math
import pandas as pd
import numpy as np
import copy
import string
import random
import itertools
import time
import csv
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import statistics
from mpl_toolkits.mplot3d import axes3d, Axes3D
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

# %%
all_texts=[]
Y = []
dictionary= {}
start = time.process_time()
os.chdir("C://Users//Hp//Desktop//Projects//Text-Mining//Reviews")
# os.chdir("C://Users//Hp//Desktop//Projects//Text-Mining//bbc")
directories = os.listdir()
label = 0
for directory in directories:
    path = os.path.join(os.getcwd(),directory)
    os.chdir(path)
    files = os.listdir()
    temp = []
    for file in files:
        with open(file,'r') as curr_file:
            all_texts.append(curr_file.read())
            Y.append(label)
    label = label + 1
    os.chdir('..')
os.chdir('..')
path = os.path.join(os.getcwd(),"GA")
os.chdir(path)
tfidf = TfidfVectorizer(all_texts, stop_words='english')
vectors = tfidf.fit_transform(all_texts)
all_words = tfidf.get_feature_names()
vectors_dense = vectors.todense()
svd = TruncatedSVD(n_components=3)
vectors_dense_svd = svd.fit_transform(vectors_dense)
vectors_dense_svd = Normalizer().fit_transform(vectors_dense_svd)
end = time.process_time()
print("Time to pre-process : "+str(end-start))
fig=plt.figure()
X = vectors_dense_svd
ax = Axes3D(fig)
print("Number of documents: "+str(len(X)))
for j in range(len(X)):
    temp = ' '.join(map(str, X[j]))
    dictionary[temp]=Y[j]
    ax.scatter(X[j][0], X[j][1], X[j][2], marker='o')
    ax.view_init(330, 120)
# Out:
# Time to pre-process : 11.59375
# [[ 0.86899966 -0.4089477  -0.27857023]
#  [ 0.77130724  0.63564904  0.03217846]
#  [ 0.95617665 -0.20739444 -0.20667308]
#  ...
#  [ 0.92566133  0.3713165  -0.0726303 ]
#  [ 0.99528814  0.0182206  -0.09523408]
#  [ 0.99419871  0.091301   -0.05686   ]]

# %%
K=7
P=30
cross_over_rate=0.1
mutation_rate=0.01
number_of_generations=100

# %%
def population_initialization():
    '''
    Parameters:
    Output:
        P chromosomes of length K*N where N is the number of features
    Function:
        Takes K random datapoints from the dataset and appends them to create a chromosome
        This is repeated P times
    '''
    population=[]
    for i in range(P):
        chromosome=[]
        for j in range(K):
            chromosome.append(X[random.randint(0,len(X)-1)])
        chromosome=list(itertools.chain(*chromosome))
        population.append(chromosome)
    return population

# %%
#Function to decide cluster using Euclidean distance
def cosine_similarity(centers,datapoint):
    '''
    Parameters:
        centers: List of Cluster centers
        K : number of clusters
        datapoint : Datapoint
    Output:
        Cluster number alloted based on maximum cosine_similarity of the datapoint with the cluster centers
    '''
    #Cosine Similarity    
    t = np.asarray(datapoint)
    normt= np.linalg.norm(t)
    dot=[]
    for i in range(K):
        temp_center = np.asarray(centers[i])
        normc = np.linalg.norm(temp_center)
        cos_sim_value=np.dot(t,temp_center)/(normt*normc)
        dot.append(cos_sim_value)
    
    return dot.index(max(dot))

# %%
def euclidean_dist_based_center_decision(centers,datapoint):
    t = np.asarray(datapoint)
    dist=[]
    for i in range(K):
        temp_center = np.asarray(centers[i])
        dist.append(np.sqrt(np.sum(np.square(temp_center-t))))
    return dist.index(min(dist))

# %%
def fitness_function(chromosome):
    '''
    Parameters:
        K: Number of clusters
        chromosome: Contains the centers of K clusters
        X : dataset
    Output:
        A fitness value f for the input chromosome
    Function:
        1. Initializes K centers using the chromosome
        2. Divides the dataset into K clusters using functions like cosine_similarity or euclidean_distance
        3. Recomputer cluster centers by averaging the datapoints of that cluster
        4. Computer fitness value as follows:
                M = sum from i in range(1,K)(Mi)
                Mi= sum of distances of datapoints of a cluster from its center
                fitness_value(f) = 1/M
    '''
    centers=[]
    
    #Dividing the chromosomes into centers
    for i in range(K):
        centers.append(chromosome[i*len(X[0]):len(X[0])*(i+1)])
    
    #Dividing the dataset into clusters
    clusters={}
    for i in range(K):
        clusters[i]=[]
    for i in range(len(X)):
#         clusters[euclidean_dist_based_center_decision(centers,X[i])].append(X[i])
        clusters[cosine_similarity(centers,X[i])].append(X[i])
    
    n_components=2
    svd = TruncatedSVD(n_components)
    U  = []
    for i in range(K):
        if(len(clusters[i])!=0):
            U.append(svd.fit_transform(clusters[i]))
    
    theta=0
    for i in range(n_components):
        for j in range(len(U)):
            for k in range(len(U)):
                if k!=j and (U[k].shape)[1]==(U[j].shape)[1]:
                    t1 = U[j][i]
                    t2 = U[k][i]
                    temp = np.dot(t1,t2)/(np.linalg.norm(t1)*np.linalg.norm(t2))
                    theta=theta+math.acos(temp)
        
    #Recomputing cluster centers
    centers=[]
    for i in range(K):
        temp=clusters[i]
        if len(temp)!=0:
            centers.append((np.sum(np.asarray(temp),axis=0)/len(temp)).tolist())
        else:
            temp_list=X[random.randint(0,len(X)-1)]
            centers.append(temp_list)
    
    chromosome =[]
    for i in range(len(centers)):
        chromosome.extend(centers[i])
    fitness_score = theta
    return fitness_score,chromosome

# %%
def fitness_evaluation(population):
    '''
    Parameters:
        K: Number of clusters
        population: Contains all the chromosomes of the current generation
        X : dataset
    Output:
        A list of fitness scores of each chromosome in the parent
    '''
    fitness=[]
    pop = []
    for i in population:
        fitness_value,recomputed_chromosome = fitness_function(i)
        fitness.append(fitness_value)
        pop.append(recomputed_chromosome)
    return pop,fitness

# %%
def roulette_wheel(fitness_scores):
    sum_fitness_scores = np.sum(np.asarray(fitness_scores))
    temp_fitness = copy.deepcopy(fitness_scores)
    temp_fitness.sort(reverse=True)
    t=[]
    for i in range(len(fitness_scores)):
        percentage_coverage=int(temp_fitness[i]*360/sum_fitness_scores)
        for j in range(percentage_coverage):
            t.append(i)
    
    temp=[]
    for i in range(2):
        toss=random.randint(0,len(t)-1)
        temp.append(t[toss])
    return temp

# %%
def cross_over(parent1,parent2,parent1_f_val,parent2_f_val):
    temp = {}
    fitness_scores=[]
    fitness_scores.append(parent1_f_val)
    fitness_scores.append(parent2_f_val)
    temp[parent1_f_val]=parent1
    temp[parent2_f_val]=parent2
    for i in range(1,len(parent1)-1):
        prob_of_cross_over_point = np.random.random_sample()
        if prob_of_cross_over_point<cross_over_rate:
            left_parent_1 = parent1[:i]
            right_parent_1= parent1[i:]
            left_parent_2 = parent2[:i]
            right_parent_2= parent2[i:]
            child1 = left_parent_1
            child2 = left_parent_2
            child1.extend(right_parent_2)
            child2.extend(right_parent_1)
            _,fitness_values = fitness_evaluation([child1,child2])
            temp[fitness_values[0]]=child1
            temp[fitness_values[1]]=child2
            fitness_scores.extend(fitness_values)
    max1=max(fitness_scores)
    fitness_scores.remove(max1)
    max2=max(fitness_scores)
    return temp[max1],temp[max2]

# %%
def cross_over_function(population,fitness_scores):
    '''
    Parameters:
        population: Parent population chromosomes
        fitness_scores: fitness of parent population
    Output:
        children generation population
    Function:
        We select the 2 best chromosomes and 2 worst chromosomes and perform a cross-over between the bests and worsts and add
        them to the population generating children generation population with 4 different chromosomes.
    '''
    for i in range(P//2):
        t=roulette_wheel(fitness_scores)
        t.sort()
        c1i,c2i=t[0:2]
        chromosome1 = population[c1i]
        chromosome2 = population[c2i]

        c1,c2 = cross_over(chromosome1,chromosome2,fitness_scores[c1i],fitness_scores[c2i])

        population.append(c1)
        population.append(c2)

        del(population[c1i])
        del(fitness_scores[c1i])
        c2i=max(0,c2i-1)
        del(population[c2i])
        del(fitness_scores[c2i])

        t,fitness = fitness_evaluation([c1,c2])
        fitness_scores.extend(fitness)
    return population,fitness_scores

# %%
def mutation(children):
    '''
    Parameters:
        children: Children we get from the genetic cross-over in the previous stage
        mutation_rate: Rate at which we want to mutate the children (0-1)
    Output:
        children with a mutated gene
    Functions:
        We randomly select a number between 0 and 1 using probably a gaussian distribution as mutation is not a frequent
        phenomenon. If that value is less than mutation_rate we mutate the children.
        For mutation we again generate a value alpha between 0 to 1. We then randomly select a position from the chromosome
        and changes its value as following
            let the value at the randomly selected position be v
            v = v (+/-) 2*alpha*v if(v!=0)
            v = v (+/-) 2*alpha   if(v==0)
        (+/-) is selected randomly giving each a 50-50 chance
    '''
    for i in range(len(children)):
        temp = np.random.rand(1)[0]
        if temp<mutation_rate:
            chromosome = children[i]
            position = random.randint(0,len(chromosome)-1)
            chromosome[position]=abs(1-chromosome[position])
            children[i]=chromosome
            
    return children

# %% [markdown]
# Cluster purity measure indexes

# %%
def intracluster_distances(chromosome):
    centers=[]
    
    #Dividing the chromosomes into centers
    for i in range(K):
        centers.append(chromosome[i*len(X[0]):len(X[0])*(i+1)])
    
    #Dividing the dataset into clusters
    clusters={}
    for i in range(K):
        clusters[i]=[]
    for i in range(len(X)):
#         clusters[euclidean_dist_based_center_decision(centers,X[i])].append(X[i])
        clusters[cosine_similarity(centers,X[i])].append(X[i])
   
    intracluster_d=[]
    for i in range(K):
        M=0
        temp=clusters[i]
        center=centers[i]
        for j in temp:
            M+=np.linalg.norm(np.asarray(j)-np.asarray(center))
        if len(temp)==0:
            M=0
        else:
            M=M/len(temp)
        intracluster_d.append(M)
    return intracluster_d

# %%
def davies_bouldin_index(chromosome):
    intra_distance = intracluster_distances(chromosome)
    
    centers=[]
    #Dividing the chromosomes into centers
    for i in range(K):
        centers.append(chromosome[i*len(X[0]):len(X[0])*(i+1)])
    
    D = []
    for i in range(K):
        R = []
        for j in range(K):
            if i!=j:
                M = np.linalg.norm(np.asarray(centers[i])-np.asarray(centers[j]))
                r = (intra_distance[i]+intra_distance[j])/M
                R.append(r)
        D.append(max(R))
    return (1/K)*(np.sum(np.asarray(D)))

# %%
def silhoutette_index(chromosome):
    centers=[]
    #Dividing the chromosomes into centers
    for i in range(K):
        centers.append(chromosome[i*len(X[0]):len(X[0])*(i+1)])
        
    #Dividing the dataset into clusters
    clusters={}
    for i in range(K):
        clusters[i]=[]
    for i in range(len(X)):
        clusters[cosine_similarity(centers,X[i])].append(X[i])
#         clusters[euclidean_dist_based_center_decision(centers,X[i])].append(X[i])

    S = 0
    for i in range(K):
        for j in clusters[i]:
            a = 0
            b = 0
            t1 = np.asarray(j)
            for k in clusters[i]:
                t2 = np.asarray(k)
                a  = a + np.sqrt(np.sum(np.square(t1-t2)))
            for k in range(K):
                if i!=k:
                    for f in clusters[k]:
                        t2 = np.asarray(f)
                        b  = b + np.sqrt(np.sum(np.square(t1-t2)))
            s = abs(a-b)/max(a,b)
            S = S + s
    S = S/len(X)
    return S

# %%
def calinski_harabasz(chromsome):
    centers=[]
    #Dividing the chromosomes into centers
    for i in range(K):
        centers.append(chromosome[i*len(X[0]):len(X[0])*(i+1)])
        
    #Dividing the dataset into clusters
    clusters={}
    for i in range(K):
        clusters[i]=[]
    for i in range(len(X)):
        clusters[cosine_similarity(centers,X[i])].append(X[i])
#         clusters[euclidean_dist_based_center_decision(centers,X[i])].append(X[i])
    
    #1. Calculating SSb:
    SSb = 0
    m = np.mean(X)
    for i in range(K):
        SSb += len(clusters[i])*np.square(np.linalg.norm(centers[i]-m))
    
    #2. Calculating SSw:
    SSw = 0
    for i in range(K):
        for j in clusters[i]:
            SSw += np.square(np.linalg.norm(j-centers[i]))
    
    ch_index = (SSb/SSw)*((len(X)-K)/(K-1))
    return ch_index

# %%
def dunn_index(chromosome):
    centers=[]
    #Dividing the chromosomes into centers
    for i in range(K):
        centers.append(chromosome[i*len(X[0]):len(X[0])*(i+1)])
        
    #Dividing the dataset into clusters
    clusters={}
    for i in range(K):
        clusters[i]=[]
    for i in range(len(X)):
        clusters[cosine_similarity(centers,X[i])].append(X[i])
#         clusters[euclidean_dist_based_center_decision(centers,X[i])].append(X[i])
    
    numerator = 10000000
    denominator=1
    for i in range(K):
        for j in range(K):
            if i!=j:
                numerator = min(numerator, np.sqrt(np.sum(np.square(np.asarray(centers[i])-np.asarray(centers[j])))))
    
    denominator = max(intracluster_distances(chromosome))
    return numerator/denominator

# %%
def supervised_scores(chromosome):
    centers=[]
    #Dividing the chromosomes into centers
    for i in range(K):
        centers.append(chromosome[i*len(X[0]):len(X[0])*(i+1)])
        
    #Dividing the dataset into clusters
    clusters={}
    for i in range(K):
        clusters[i]=[]
    for i in range(len(X)):
        clusters[cosine_similarity(centers,X[i])].append(X[i])
#         clusters[euclidean_dist_based_center_decision(centers,X[i])].append(X[i])
    
    
    Y_actual=[]
    Y_pred=[]
    for i in range(K):
        t=[]
        for j in range(len(clusters[i])):
            temp = ' '.join(map(str, clusters[i][j]))
            Y_actual.append(dictionary[temp])
            t.append(dictionary[temp])
        print(t)
        pred = statistics.mode(t)
        print(pred)
        for j in range(len(clusters[i])):
            Y_pred.append(pred)
            
    print(confusion_matrix(Y_actual, Y_pred))
    return f1_score(Y, Y_pred, average='micro'), accuracy_score(Y, Y_pred)

# %%
def main_func():
    '''
    Steps:
    Repeat 1-5 till 1 chromosome remains in the population
    1.Initialize Population
    2.Compute fitness scores
    3.Selection
    4.Cross-over
    5.Mutation
    '''
    start = time.process_time()
    population = population_initialization()
    gen=0
    return_chromosome=[]
    gen_fitness = []
    for i in range(number_of_generations):
        gen+=1
        population,fitness=fitness_evaluation(population)
        children,fitness = cross_over_function(population,fitness)
        children = mutation(children)
        population=children
        temp = []
        temp.append(str(gen))
        temp.append(str(max(fitness)))
        gen_fitness.append(temp)
        print("Generation: "+str(gen)+" | Best fitness: "+str(max(fitness)))
    end = time.process_time()
    print("Time taken: " + str(end-start))
    with open('GA with K='+str(K)+'.csv','w+') as csvFile:
        writer = csv.writer(csvFile)
        writer.writerows(gen_fitness)
    csvFile.close()
    return population[fitness.index(max(fitness))]

# %%
def plot(chromosome):
    centers=[]
    
    #Dividing the chromosomes into centers
    for i in range(K):
        centers.append(chromosome[i*len(X[0]):len(X[0])*(i+1)])
    
    #Dividing the dataset into clusters
    clusters={}
    for i in range(K):
        clusters[i]=[]
    for i in range(len(X)):
        clusters[cosine_similarity(centers,X[i])].append(X[i])
#         clusters[euclidean_dist_based_center_decision(centers,X[i])].append(X[i])
    
    for i in range(K):
        print(len(clusters[i]))
    colors=['#ff3333','#000000','#ffd933','#99ddff','#84ff33','#33ffee','#3395ff','#d2a8fc','#abcdef']
    fig=plt.figure()
    ax = Axes3D(fig)
    for i in range(K):
        temp=clusters[i]
        for j in temp:
            ax.scatter(j[0], j[1], j[2], c=colors[i], marker='o')
            ax.view_init(330, 140)
    for i in range(K):
        temp=clusters[i]
        ax.scatter(centers[i][0],centers[i][1],centers[i][2],c='b',marker='X')

# %%
K = 3
chromosome = main_func()
print("DB Index        :"+str(davies_bouldin_index(chromosome)))
print("Silhoutte Index :"+str(silhoutette_index(chromosome)))
print("Calinski-Harabasz Index :"+str(calinski_harabasz(chromosome)))
plot(chromosome)
# Out:
# Generation: 1 | Best fitness: 6.779357769933734
# Generation: 2 | Best fitness: 7.366468382391427
# Generation: 3 | Best fitness: 7.2943717268824715
# Generation: 4 | Best fitness: 6.175443067955353
# Generation: 5 | Best fitness: 8.558163001013
# Generation: 6 | Best fitness: 8.558163001013014
# Generation: 7 | Best fitness: 6.452559313720328
# Generation: 8 | Best fitness: 7.091427018407314
# Generation: 9 | Best fitness: 7.752948052073571
# Generation: 10 | Best fitness: 7.634168313071404
# Generation: 11 | Best fitness: 5.642797683508083
# Generation: 12 | Best fitness: 9.3726680183964
# Generation: 13 | Best fitness: 7.437266035707802
# Generation: 14 | Best fitness: 7.437266035707825
# Generation: 15 | Best fitness: 6.620430061506487
# Generation: 16 | Best fitness: 7.012834657827625
# Generation: 17 | Best fitness: 7.877973168507116
# Generation: 18 | Best fitness: 7.050570831169274
# Generation: 19 | Best fitness: 9.407359275985575
# Generation: 20 | Best fitness: 8.348409032280598
# Generation: 21 | Best fitness: 9.367818592333874
# Generation: 22 | Best fitness: 6.3323699379255896
# Generation: 23 | Best fitness: 7.2279158974873
# Generation: 24 | Best fitness: 8.37830338205683
# Generation: 25 | Best fitness: 7.861807488376089
# Generation: 26 | Best fitness: 7.314810001199644
# Generation: 27 | Best fitness: 7.314810001199641
# Generation: 28 | Best fitness: 8.428713956086261
# Generation: 29 | Best fitness: 7.165593331170031
# Generation: 30 | Best fitness: 6.71985567058182
# Generation: 31 | Best fitness: 7.839061673875417
# Generation: 32 | Best fitness: 7.480186355744571
# Generation: 33 | Best fitness: 9.81922159643044
# Generation: 34 | Best fitness: 7.2355088429099945
# Generation: 35 | Best fitness: 9.262059170500274
# Generation: 36 | Best fitness: 8.491289948994307
# Generation: 37 | Best fitness: 7.306898974183973
# Generation: 38 | Best fitness: 7.67607367060823
# Generation: 39 | Best fitness: 8.199173132942883
# Generation: 40 | Best fitness: 8.199173132942839
# Generation: 41 | Best fitness: 8.624363256015073
# Generation: 42 | Best fitness: 8.624363256015073
# Generation: 43 | Best fitness: 7.814956195938541
# Generation: 44 | Best fitness: 7.966269555737804
# Generation: 45 | Best fitness: 7.646844187045529
# Generation: 46 | Best fitness: 7.9381140551066895
# Generation: 47 | Best fitness: 9.722561315551722
# Generation: 48 | Best fitness: 7.6292991714149005
# Generation: 49 | Best fitness: 6.4717939447157935
# Generation: 50 | Best fitness: 6.471793944715818
# Generation: 51 | Best fitness: 6.211512947849953
# Generation: 52 | Best fitness: 9.377768662193793
# Generation: 53 | Best fitness: 7.510346334273043
# Generation: 54 | Best fitness: 5.590337503361628
# Generation: 55 | Best fitness: 6.513882060943281
# Generation: 56 | Best fitness: 7.304521748043357
# Generation: 57 | Best fitness: 6.980852497776491
# Generation: 58 | Best fitness: 6.2039932773244555
# Generation: 59 | Best fitness: 14.250973590752093
# Generation: 60 | Best fitness: 14.250973590752073
# Generation: 61 | Best fitness: 9.337007130428532
# Generation: 62 | Best fitness: 7.152530636958717
# Generation: 63 | Best fitness: 7.152530636958748
# Generation: 64 | Best fitness: 5.932552489469396
# Generation: 65 | Best fitness: 8.747016034406391
# Generation: 66 | Best fitness: 6.495129198376055
# Generation: 67 | Best fitness: 7.342054448431263
# Generation: 68 | Best fitness: 7.808292376728819
# Generation: 69 | Best fitness: 7.743976093487202
# Generation: 70 | Best fitness: 6.791239483612105
# Generation: 71 | Best fitness: 7.99442296325422
# Generation: 72 | Best fitness: 8.913518185033103
# Generation: 73 | Best fitness: 8.242605305986164
# Generation: 74 | Best fitness: 10.32424361006029
# Generation: 75 | Best fitness: 8.393954330122659
# Generation: 76 | Best fitness: 8.215224801113093
# Generation: 77 | Best fitness: 5.741673421912335
# Generation: 78 | Best fitness: 6.552282665547175
# Generation: 79 | Best fitness: 9.37094605652622
# Generation: 80 | Best fitness: 9.37094605652614
# Generation: 81 | Best fitness: 7.832514134140866
# Generation: 82 | Best fitness: 7.920959326251277
# Generation: 83 | Best fitness: 7.920959326251252
# Generation: 84 | Best fitness: 7.435784271825103
# Generation: 85 | Best fitness: 7.435784271825147
# Generation: 86 | Best fitness: 7.138790419407362
# Generation: 87 | Best fitness: 7.896246968269355
# Generation: 88 | Best fitness: 6.361410445743822
# Generation: 89 | Best fitness: 7.972980385353677
# Generation: 90 | Best fitness: 8.896987543076147
# Generation: 91 | Best fitness: 5.642040429591777
# Generation: 92 | Best fitness: 8.520410261056952
# Generation: 93 | Best fitness: 6.663449104542796
# Generation: 94 | Best fitness: 6.663449104542799
# Generation: 95 | Best fitness: 6.554671310100986
# Generation: 96 | Best fitness: 7.297225961678246
# Generation: 97 | Best fitness: 7.2972259616782456
# Generation: 98 | Best fitness: 5.025353875261944
# Generation: 99 | Best fitness: 5.036701849232311
# Generation: 100 | Best fitness: 6.818743626597783
# Time taken: 2353.4375
# DB Index        :6.945571306260128
# Silhoutte Index :0.48499744437179115
# Calinski-Harabasz Index :6753.208563918529
# 838
# 2023
# 1208

# %%
K = 5
chromosome = main_func()
print("DB Index        :"+str(davies_bouldin_index(chromosome)))
print("Silhoutte Index :"+str(silhoutette_index(chromosome)))
print("Calinski-Harabasz Index :"+str(calinski_harabasz(chromosome)))
plot(chromosome)
# Out:
# Generation: 1 | Best fitness: 26.47573834377188
# Generation: 2 | Best fitness: 26.475738343771898
# Generation: 3 | Best fitness: 20.22552884614439
# Generation: 4 | Best fitness: 15.690626409515605
# Generation: 5 | Best fitness: 21.077466343167863
# Generation: 6 | Best fitness: 25.972527561993175
# Generation: 7 | Best fitness: 20.274213957042466
# Generation: 8 | Best fitness: 20.27421395704234
# Generation: 9 | Best fitness: 25.21566743361565
# Generation: 10 | Best fitness: 15.422283800083171
# Generation: 11 | Best fitness: 16.927955622199853
# Generation: 12 | Best fitness: 24.046672453804312
# Generation: 13 | Best fitness: 17.30207520007987
# Generation: 14 | Best fitness: 21.140271234848
# Generation: 15 | Best fitness: 23.211726570449496
# Generation: 16 | Best fitness: 22.117481477335915
# Generation: 17 | Best fitness: 22.117481477336
# Generation: 18 | Best fitness: 16.04401297644274
# Generation: 19 | Best fitness: 15.909669072117689
# Generation: 20 | Best fitness: 20.89400641433683
# Generation: 21 | Best fitness: 17.258170379287122
# Generation: 22 | Best fitness: 17.23558463248422
# Generation: 23 | Best fitness: 17.233617414787048
# Generation: 24 | Best fitness: 17.547985107359096
# Generation: 25 | Best fitness: 33.242219529881766
# Generation: 26 | Best fitness: 18.647222469228442
# Generation: 27 | Best fitness: 27.788753649329713
# Generation: 28 | Best fitness: 21.352918220590034
# Generation: 29 | Best fitness: 19.28656775672663
# Generation: 30 | Best fitness: 17.68065088745914
# Generation: 31 | Best fitness: 19.09539082520769
# Generation: 32 | Best fitness: 20.495213914362218
# Generation: 33 | Best fitness: 24.76979009274807
# Generation: 34 | Best fitness: 23.105441876204075
# Generation: 35 | Best fitness: 15.959662772514983
# Generation: 36 | Best fitness: 20.861158757886265
# Generation: 37 | Best fitness: 20.861158757886248
# Generation: 38 | Best fitness: 22.17213082679598
# Generation: 39 | Best fitness: 17.258944433540044
# Generation: 40 | Best fitness: 17.316776644698304
# Generation: 41 | Best fitness: 17.394252382079898
# Generation: 42 | Best fitness: 17.379193652597646
# Generation: 43 | Best fitness: 17.306845554813165
# Generation: 44 | Best fitness: 17.306845554813208
# Generation: 45 | Best fitness: 17.347869670293903
# Generation: 46 | Best fitness: 17.42947127470363
# Generation: 47 | Best fitness: 17.372102188566966
# Generation: 48 | Best fitness: 17.340099633472096
# Generation: 49 | Best fitness: 17.43921648560696
# Generation: 50 | Best fitness: 17.66576327227672
# Generation: 51 | Best fitness: 17.367840181884414
# Generation: 52 | Best fitness: 17.37911318232047
# Generation: 53 | Best fitness: 17.44555534998302
# Generation: 54 | Best fitness: 17.44495026357404
# Generation: 55 | Best fitness: 17.395750815999364
# Generation: 56 | Best fitness: 17.449932625730575
# Generation: 57 | Best fitness: 17.449932625730558
# Generation: 58 | Best fitness: 17.41195002408709
# Generation: 59 | Best fitness: 17.40621441738189
# Generation: 60 | Best fitness: 17.384239559305296
# Generation: 61 | Best fitness: 17.35713125845295
# Generation: 62 | Best fitness: 17.350578862206294
# Generation: 63 | Best fitness: 17.35057886220629
# Generation: 64 | Best fitness: 17.28974920201534
# Generation: 65 | Best fitness: 17.289749202015287
# Generation: 66 | Best fitness: 17.279532951762878
# Generation: 67 | Best fitness: 17.27893309350008
# Generation: 68 | Best fitness: 17.269277584575946
# Generation: 69 | Best fitness: 17.2639695262736
# Generation: 70 | Best fitness: 17.263969526273574
# Generation: 71 | Best fitness: 17.263969526273623
# Generation: 72 | Best fitness: 17.263969526273534
# Generation: 73 | Best fitness: 17.385103680359173
# Generation: 74 | Best fitness: 17.385103680359098
# Generation: 75 | Best fitness: 17.283183888094555
# Generation: 76 | Best fitness: 17.278933093500108
# Generation: 77 | Best fitness: 17.271930987439053
# Generation: 78 | Best fitness: 17.614757344568428
# Generation: 79 | Best fitness: 17.536997004283663
# Generation: 80 | Best fitness: 17.464735829481043
# Generation: 81 | Best fitness: 17.464735829481054
# Generation: 82 | Best fitness: 17.33949212383911
# Generation: 83 | Best fitness: 17.351515479074035
# Generation: 84 | Best fitness: 17.351515479073985
# Generation: 85 | Best fitness: 17.35472495093522
# Generation: 86 | Best fitness: 17.48596705625533
# Generation: 87 | Best fitness: 17.385783526213267
# Generation: 88 | Best fitness: 17.37373196954121
# Generation: 89 | Best fitness: 17.39228567805972
# Generation: 90 | Best fitness: 17.375556091494953
# Generation: 91 | Best fitness: 17.35540293173336
# Generation: 92 | Best fitness: 17.295115360106315
# Generation: 93 | Best fitness: 17.29511536010639
# Generation: 94 | Best fitness: 17.279532951762842
# Generation: 95 | Best fitness: 17.269277584576006
# Generation: 96 | Best fitness: 17.269277584575995
# Generation: 97 | Best fitness: 17.26396952627357
# Generation: 98 | Best fitness: 17.263969526273566
# Generation: 99 | Best fitness: 17.266915833745355
# Generation: 100 | Best fitness: 17.266691022801744
# Time taken: 4364.59375
# DB Index        :0.832484428470028
# Silhoutte Index :0.8554779330258084
# Calinski-Harabasz Index :20344.099114564953
# 1343
# 878
# 282
# 1513
# 53

# %%
K = 7
chromosome = main_func()
print("DB Index        :"+str(davies_bouldin_index(chromosome)))
print("Silhoutte Index :"+str(silhoutette_index(chromosome)))
print("Calinski-Harabasz Index :"+str(calinski_harabasz(chromosome)))
plot(chromosome)
# Out:
# Generation: 1 | Best fitness: 27.652151234881067
# Generation: 2 | Best fitness: 27.65215123488109
# Generation: 3 | Best fitness: 36.72058233477152
# Generation: 4 | Best fitness: 29.26693554953592
# Generation: 5 | Best fitness: 33.59333875867256
# Generation: 6 | Best fitness: 29.92013573201263
# Generation: 7 | Best fitness: 29.920135732012522
# Generation: 8 | Best fitness: 30.07437876406634
# Generation: 9 | Best fitness: 30.07437876406682
# Generation: 10 | Best fitness: 37.99444020667951
# Generation: 11 | Best fitness: 35.818531261114195
# Generation: 12 | Best fitness: 35.19778984325124
# Generation: 13 | Best fitness: 28.894602083622875
# Generation: 14 | Best fitness: 27.941063527323777
# Generation: 15 | Best fitness: 27.020460827935228
# Generation: 16 | Best fitness: 28.89105684738506
# Generation: 17 | Best fitness: 27.391843572642614
# Generation: 18 | Best fitness: 32.54805464288909
# Generation: 19 | Best fitness: 32.54805464288944
# Generation: 20 | Best fitness: 28.02312277203519
# Generation: 21 | Best fitness: 28.023122772035066
# Generation: 22 | Best fitness: 25.058593998943547
# Generation: 23 | Best fitness: 25.417821042859156
# Generation: 24 | Best fitness: 26.024622201519566
# Generation: 25 | Best fitness: 26.024622201519513
# Generation: 26 | Best fitness: 25.36636911944161
# Generation: 27 | Best fitness: 36.86453129861297
# Generation: 28 | Best fitness: 36.86453129861309
# Generation: 29 | Best fitness: 28.203729232249163
# Generation: 30 | Best fitness: 26.555114838308995
# Generation: 31 | Best fitness: 24.683196609345366
# Generation: 32 | Best fitness: 29.18202371056331
# Generation: 33 | Best fitness: 27.707350013107018
# Generation: 34 | Best fitness: 26.56021040407642
# Generation: 35 | Best fitness: 28.381183987169013
# Generation: 36 | Best fitness: 26.872654266441117
# Generation: 37 | Best fitness: 27.312578447589072
# Generation: 38 | Best fitness: 24.738241663706226
# Generation: 39 | Best fitness: 27.052693769201024
# Generation: 40 | Best fitness: 27.05269376920088
# Generation: 41 | Best fitness: 26.641342681593684
# Generation: 42 | Best fitness: 24.67932139045464
# Generation: 43 | Best fitness: 25.764856531339873
# Generation: 44 | Best fitness: 25.764856531340065
# Generation: 45 | Best fitness: 26.19172986387405
# Generation: 46 | Best fitness: 26.191729863874023
# Generation: 47 | Best fitness: 24.088000117332225
# Generation: 48 | Best fitness: 22.2922317813096
# Generation: 49 | Best fitness: 25.617454155984852
# Generation: 50 | Best fitness: 25.617454155984706
# Generation: 51 | Best fitness: 28.63866190159243
# Generation: 52 | Best fitness: 29.16540470474867
# Generation: 53 | Best fitness: 29.165404704748664
# Generation: 54 | Best fitness: 32.531835048698056
# Generation: 55 | Best fitness: 26.301458437577406
# Generation: 56 | Best fitness: 24.89663468697345
# Generation: 57 | Best fitness: 25.700926568919556
# Generation: 58 | Best fitness: 25.63757126151011
# Generation: 59 | Best fitness: 25.912392206466947
# Generation: 60 | Best fitness: 25.912392206466663
# Generation: 61 | Best fitness: 25.72321053348181
# Generation: 62 | Best fitness: 25.723210533481627
# Generation: 63 | Best fitness: 25.271686460202517
# Generation: 64 | Best fitness: 24.918230022321435
# Generation: 65 | Best fitness: 24.375843995740375
# Generation: 66 | Best fitness: 23.926046109853623
# Generation: 67 | Best fitness: 25.62314289793069
# Generation: 68 | Best fitness: 25.623142897930514
# Generation: 69 | Best fitness: 20.61346814728529
# Generation: 70 | Best fitness: 19.116594576405927
# Generation: 71 | Best fitness: 19.116594576406147
# Generation: 72 | Best fitness: 19.55356111785766
# Generation: 73 | Best fitness: 20.31578736192618
# Generation: 74 | Best fitness: 20.31578736192592
# Generation: 75 | Best fitness: 19.934385825022005
# Generation: 76 | Best fitness: 20.10772068271562
# Generation: 77 | Best fitness: 20.17199207613114
# Generation: 78 | Best fitness: 20.38853517859561
# Generation: 79 | Best fitness: 20.323944447380534
# Generation: 80 | Best fitness: 20.343052634385387
# Generation: 81 | Best fitness: 20.695551574560653
# Generation: 82 | Best fitness: 21.706684856645346
# Generation: 83 | Best fitness: 21.73623311798993
# Generation: 84 | Best fitness: 22.44947535967926
# Generation: 85 | Best fitness: 22.669045718362078
# Generation: 86 | Best fitness: 23.651884529042583
# Generation: 87 | Best fitness: 24.792632298803305
# Generation: 88 | Best fitness: 26.59930305343734
# Generation: 89 | Best fitness: 24.63694042045507
# Generation: 90 | Best fitness: 23.75263130835412
# Generation: 91 | Best fitness: 24.99581174676781
# Generation: 92 | Best fitness: 24.995811746767895
# Generation: 93 | Best fitness: 25.28020007278028
# Generation: 94 | Best fitness: 25.916767284473305
# Generation: 95 | Best fitness: 22.55800757273129
# Generation: 96 | Best fitness: 21.95392948352608
# Generation: 97 | Best fitness: 23.23615293129698
# Generation: 98 | Best fitness: 24.498577538798145
# Generation: 99 | Best fitness: 25.500258035733424
# Generation: 100 | Best fitness: 25.575562945248585
# Time taken: 5996.71875
# DB Index        :0.8936820156030754
# Silhoutte Index :0.9049625670370102
# Calinski-Harabasz Index :19764.63901660177
# 1016
# 1578
# 49
# 503
# 551
# 158
# 214

# %%
K = 9
chromosome = main_func()
print("DB Index        :"+str(davies_bouldin_index(chromosome)))
print("Silhoutte Index :"+str(silhoutette_index(chromosome)))
print("Calinski-Harabasz Index :"+str(calinski_harabasz(chromosome)))
plot(chromosome)
# Out:
# Generation: 1 | Best fitness: 43.722021273398944
# Generation: 2 | Best fitness: 45.35480125069342
# Generation: 3 | Best fitness: 41.21218009704734
# Generation: 4 | Best fitness: 45.58293966521603
# Generation: 5 | Best fitness: 45.58293966521638
# C:\Users\Hp\Anaconda3\lib\site-packages\sklearn\decomposition\truncated_svd.py:191: RuntimeWarning: invalid value encountered in true_divide
#   self.explained_variance_ratio_ = exp_var / full_var
# Generation: 6 | Best fitness: 50.88379198435756
# Generation: 7 | Best fitness: 42.930043389918666
# Generation: 8 | Best fitness: 49.20885849862726
# Generation: 9 | Best fitness: 47.724243292216116
# Generation: 10 | Best fitness: 53.3151923518178
# Generation: 11 | Best fitness: 53.31519235181795
# Generation: 12 | Best fitness: 63.3226478951417
# Generation: 13 | Best fitness: 48.26922477476999
# Generation: 14 | Best fitness: 53.640189400914466
# Generation: 15 | Best fitness: 53.640189400914466
# Generation: 16 | Best fitness: 53.59696630705514
# Generation: 17 | Best fitness: 46.74682923467098
# Generation: 18 | Best fitness: 48.14874270724912
# Generation: 19 | Best fitness: 48.148742707248275
# Generation: 20 | Best fitness: 45.566383960060605
# Generation: 21 | Best fitness: 45.56638396006045
# Generation: 22 | Best fitness: 51.29801900563724
# C:\Users\Hp\Anaconda3\lib\site-packages\sklearn\decomposition\truncated_svd.py:191: RuntimeWarning: invalid value encountered in true_divide
#   self.explained_variance_ratio_ = exp_var / full_var
# Generation: 23 | Best fitness: 51.873884446436676
# Generation: 24 | Best fitness: 54.67784161751743
# Generation: 25 | Best fitness: 49.687739099003096
# Generation: 26 | Best fitness: 46.27843966271398
# Generation: 27 | Best fitness: 46.24570873485277
# Generation: 28 | Best fitness: 42.311263934025014
# Generation: 29 | Best fitness: 48.9767780918854
# Generation: 30 | Best fitness: 44.58335258270714
# Generation: 31 | Best fitness: 46.21151938229729
# Generation: 32 | Best fitness: 46.21151938229729
# Generation: 33 | Best fitness: 43.47749215895148
# Generation: 34 | Best fitness: 43.94114137563095
# Generation: 35 | Best fitness: 43.941141375631126
# Generation: 36 | Best fitness: 42.980356766721506
# Generation: 37 | Best fitness: 43.00356036002919
# Generation: 38 | Best fitness: 41.4392049017388
# Generation: 39 | Best fitness: 42.7282111129116
# Generation: 40 | Best fitness: 42.728211112911886
# Generation: 41 | Best fitness: 37.05198470952135
# Generation: 42 | Best fitness: 40.516338036689774
# Generation: 43 | Best fitness: 40.064683222359506
# Generation: 44 | Best fitness: 39.779085508305066
# Generation: 45 | Best fitness: 38.136111529520335
# Generation: 46 | Best fitness: 42.66224194384905
# Generation: 47 | Best fitness: 45.443625155059145
# Generation: 48 | Best fitness: 40.91862847368384
# Generation: 49 | Best fitness: 41.1386350360395
# Generation: 50 | Best fitness: 43.60486181064689
# Generation: 51 | Best fitness: 43.60486181064695
# Generation: 52 | Best fitness: 38.20918144803204
# Generation: 53 | Best fitness: 40.483021726355325
# Generation: 54 | Best fitness: 37.49092396690762
# Generation: 55 | Best fitness: 37.490923966907545
# Generation: 56 | Best fitness: 38.6933126453885
# Generation: 57 | Best fitness: 36.917892117168705
# Generation: 58 | Best fitness: 36.91789211716866
# Generation: 59 | Best fitness: 43.018678626872514
# Generation: 60 | Best fitness: 39.281528576328064
# Generation: 61 | Best fitness: 39.318582056470376
# Generation: 62 | Best fitness: 39.31858205647027
# Generation: 63 | Best fitness: 38.7379189547948
# Generation: 64 | Best fitness: 35.320727606852515
# Generation: 65 | Best fitness: 35.32072760685274
# Generation: 66 | Best fitness: 33.941558536892174
# Generation: 67 | Best fitness: 33.82406396481287
# Generation: 68 | Best fitness: 37.241668722179675
# Generation: 69 | Best fitness: 37.24166872217957
# Generation: 70 | Best fitness: 33.4428055691414
# Generation: 71 | Best fitness: 33.55244267107187
# Generation: 72 | Best fitness: 33.55244267107189
# Generation: 73 | Best fitness: 32.54869475812281
# Generation: 74 | Best fitness: 33.41687684829333
# Generation: 75 | Best fitness: 33.48425704883099
# Generation: 76 | Best fitness: 33.48425704883105
# Generation: 77 | Best fitness: 33.23356798403351
# Generation: 78 | Best fitness: 32.76722323922729
# Generation: 79 | Best fitness: 32.767223239227185
# Generation: 80 | Best fitness: 32.17522028043898
# Generation: 81 | Best fitness: 31.814800529214004
# Generation: 82 | Best fitness: 31.389510310254934
# Generation: 83 | Best fitness: 34.81088003231237
# Generation: 84 | Best fitness: 31.098774642332447
# Generation: 85 | Best fitness: 31.48220262331407
# Generation: 86 | Best fitness: 32.21223010188912
# Generation: 87 | Best fitness: 31.746492757107735
# Generation: 88 | Best fitness: 39.180659556140554
# Generation: 89 | Best fitness: 30.353048742998254
# Generation: 90 | Best fitness: 31.103767318137354
# Generation: 91 | Best fitness: 30.489263441156194
# Generation: 92 | Best fitness: 34.17834987565584
# Generation: 93 | Best fitness: 34.17834987565601
# Generation: 94 | Best fitness: 30.581756606934356
# Generation: 95 | Best fitness: 33.09673306436162
# Generation: 96 | Best fitness: 32.46715803944968
# Generation: 97 | Best fitness: 34.07917828399204
# Generation: 98 | Best fitness: 35.402274841477656
# Generation: 99 | Best fitness: 34.86440170576733
# Generation: 100 | Best fitness: 34.45943370976514
# Time taken: 8339.4375
# DB Index        :0.7772738949312004
# Silhoutte Index :0.9574834920587496
# Calinski-Harabasz Index :26762.078297378543
# 527
# 122
# 782
# 49
# 462
# 308
# 147
# 1036
# 636
