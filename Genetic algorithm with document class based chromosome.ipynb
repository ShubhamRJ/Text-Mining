# %%
import nltk
import os
import re
import math
import pandas as pd
import numpy as np
import copy
import string
import random
import time
import itertools
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d, Axes3D
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer

# %%
stop_words = set(stopwords.words('english'))
tokenized_files={}
total_no_of_files=0
os.chdir("C://Users//Hp//Desktop//Projects//Text Mining//bbcsport")
directories = os.listdir()
for directory in directories:
    path = os.path.join(os.getcwd(),directory)
    os.chdir(path)
    files = os.listdir()
    temp = []
    for file in files:
        with open(file,'r') as curr_file:
            s = curr_file.read()
#             s = re.sub(r'\d+','',s)
            s = s.translate(str.maketrans("","",string.punctuation))
            s = s.lower()
            t1 = nltk.tokenize.word_tokenize(s)
            t2 = []
            for word in t1:
                if word not in stop_words:
                    t2.append(word)
            temp.append(t2)
            total_no_of_files+=1
    tokenized_files[directory]=temp
    os.chdir('..')

# %%
#Creating a unique set of all words
wordset=[]
for key in tokenized_files.keys():
    for file in tokenized_files[key]:
        for word in file:
            wordset.append(word)
                     
wordset = list(set(wordset))

# %%
#Calculating the frequency of occurence of a specific word among all documents
wordFreq={}
for word in wordset:
    count=0
    for key in tokenized_files.keys():
        for file in tokenized_files[key]:
            if word in file:
                count+=1
    wordFreq[word]=count

# %%
#Calculating the tf-idf values for all words in the wordset for all documents
X = []
for key in tokenized_files.keys():
    file_number=0
    for file in tokenized_files[key]:
        file_tfidf = []
        n = len(file)
        for word in wordset:
            a = file.count(word)
            tf= a/n
            modified_idf=math.log(1+total_no_of_files/wordFreq[word])
            normalized_tfidf =10*tf*modified_idf*(n/(n-tf+1))
            file_tfidf.append(normalized_tfidf)
        X.append(file_tfidf)
X_copy = copy.deepcopy(X)

# %%
def min_max_normalization(X):
    for i in range(len(X[0])):
        m = max(X[:,i])
        n = min(X[:,i])
        for j in range(len(X)):
            X[j][i]=(X[j][i]-n)/(m-n)
    return X

# %%
def z_score_normalization(X):
    for i in range(len(X[0])):
        avg = np.mean(X[:,i])
        std = np.std(X[:,i])
        for j in range(len(X)):
            X[j][i] = (X[j][i]-avg)/std
    return X

# %%
X = copy.deepcopy(X_copy)
X = np.array(X)
X = min_max_normalization(X)
svd = TruncatedSVD(n_components=3)
X = svd.fit_transform(X)
X = Normalizer().fit_transform(X)
fig=plt.figure()
ax = Axes3D(fig)    
for j in range(len(X)):
    ax.scatter(X[j][0], X[j][1], X[j][2], marker='o')
    ax.view_init(330, 120)

X.shape
# Out:
# (737, 3)

# %%
K=5
P=30
cross_over_rate=0.5
mutation_rate=0.1

# %%
def population_initialization():
    '''
    Parameters:
    Output:
        P chromosomes of length K*N where N is the number of features
    Function:
        Takes K random datapoints from the dataset and appends them to create a chromosome
        This is repeated P times
    '''
    population=[]
    for i in range(P):
        chromosome=[]
        for j in range(len(X)):
            chromosome.append(random.randint(0,100)%5)
        population.append(chromosome)
    return population

# %%
def fitness_function(chromosome):
    '''
    Parameters:
        K: Number of clusters
        chromosome: Contains the centers of K clusters
        X : dataset
    Output:
        A fitness value f for the input chromosome
    Function:
        1. Initializes K centers using the chromosome
        2. Divides the dataset into K clusters using functions like cosine_similarity or euclidean_distance
        3. Recomputer cluster centers by averaging the datapoints of that cluster
        4. Computer fitness value as follows:
                M = sum from i in range(1,K)(Mi)
                Mi= sum of distances of datapoints of a cluster from its center
                fitness_value(f) = 1/M
    '''
    centers=[]
    #Dividing the dataset into clusters
    clusters={}
    for i in range(K):
        clusters[i]=[]
    for i in range(len(chromosome)):
        clusters[chromosome[i]].append(X[i])
    
    n_components=2
    svd = TruncatedSVD(n_components)
    U  = []
    for i in range(K):
        if(len(clusters[i])!=0):
            U.append(svd.fit_transform(clusters[i]))
    
    theta=0
    for i in range(n_components):
        for j in range(len(U)):
            for k in range(len(U)):
                if k!=j:
                    t1 = U[j][i]
                    t2 = U[k][i]
                    temp = np.dot(t1,t2)/(np.linalg.norm(t1)*np.linalg.norm(t2))
                    theta=theta+math.acos(temp)
                    
    fitness_score = theta
    return fitness_score

# %%
def fitness_evaluation(population):
    '''
    Parameters:
        K: Number of clusters
        population: Contains all the chromosomes of the current generation
        X : dataset
    Output:
        A list of fitness scores of each chromosome in the parent
    '''
    fitness=[]
    for i in population:
        fitness_value = fitness_function(i)
        fitness.append(fitness_value)
    return fitness

# %%
def roulette_wheel(fitness_scores):
    sum_fitness_scores = np.sum(np.asarray(fitness_scores))
    temp_fitness = copy.deepcopy(fitness_scores)
    temp_fitness.sort(reverse=True)
    t=[]
    for i in range(len(fitness_scores)):
        percentage_coverage=int(temp_fitness[i]*360/sum_fitness_scores)
        for j in range(percentage_coverage):
            t.append(i)
    
    temp=[]
    for i in range(2):
        toss=random.randint(0,len(t)-1)
        temp.append(t[toss])
    return temp

# %%
def cross_over(parent1,parent2,parent1_f_val,parent2_f_val):
    temp = {}
    fitness_scores=[]
    fitness_scores.append(parent1_f_val)
    fitness_scores.append(parent2_f_val)
    temp[parent1_f_val]=parent1
    temp[parent2_f_val]=parent2
    for i in range(1,len(parent1)-1):
        prob_of_cross_over_point = np.random.random_sample()
        if prob_of_cross_over_point<cross_over_rate:
            left_parent_1 = parent1[:i]
            right_parent_1= parent1[i:]
            left_parent_2 = parent2[:i]
            right_parent_2= parent2[i:]
            child1 = left_parent_1
            child2 = left_parent_2
            child1.extend(right_parent_2)
            child2.extend(right_parent_1)
            fitness_values = fitness_evaluation([child1,child2])
            temp[fitness_values[0]]=child1
            temp[fitness_values[1]]=child2
            fitness_scores.extend(fitness_values)
    max1=max(fitness_scores)
    fitness_scores.remove(max1)
    max2=max(fitness_scores)
    return temp[max1],temp[max2]

# %%
def cross_over_function(population,fitness_scores):
    '''
    Parameters:
        population: Parent population chromosomes
        fitness_scores: fitness of parent population
    Output:
        children generation population
    Function:
        We select the 2 best chromosomes and 2 worst chromosomes and perform a cross-over between the bests and worsts and add
        them to the population generating children generation population with 4 different chromosomes.
    '''
    for i in range(P//2):
        t=roulette_wheel(fitness_scores)
        t.sort()
        c1i,c2i=t[0:2]
        chromosome1 = population[c1i]
        chromosome2 = population[c2i]

        c1,c2 = cross_over(chromosome1,chromosome2,fitness_scores[c1i],fitness_scores[c2i])

        population.append(c1)
        population.append(c2)

        del(population[c1i])
        del(fitness_scores[c1i])
        c2i=max(0,c2i-1)
        del(population[c2i])
        del(fitness_scores[c2i])

        fitness = fitness_evaluation([c1,c2])
        fitness_scores.extend(fitness)
    return population,fitness_scores

# %%
def mutation(children):
    '''
    Parameters:
        children: Children we get from the genetic cross-over in the previous stage
        mutation_rate: Rate at which we want to mutate the children (0-1)
    Output:
        children with a mutated gene
    Functions:
        We randomly select a number between 0 and 1 using probably a gaussian distribution as mutation is not a frequent
        phenomenon. If that value is less than mutation_rate we mutate the children.
        For mutation we again generate a value alpha between 0 to 1. We then randomly select a position from the chromosome
        and changes its value as following
            let the value at the randomly selected position be v
            v = v (+/-) 2*alpha*v if(v!=0)
            v = v (+/-) 2*alpha   if(v==0)
        (+/-) is selected randomly giving each a 50-50 chance
    '''
    for i in range(len(children)):
        temp = np.random.rand(1)[0]
        if temp<mutation_rate:
            chromosome = children[i]
            position = random.randint(0,len(chromosome)-1)
            chromosome[position]=abs((chromosome[position]+random.randint(0,100))%5)
            children[i]=chromosome
    return children

# %%
def intracluster_distances(chromosome):    
    #Dividing the dataset into clusters
    clusters={}
    for i in range(K):
        clusters[i]=[]
    for i in range(len(chromosome)):
        clusters[chromosome[i]]=X[i]
    
    centers=[]
    for i in range(K):
        temp=clusters[i]
        centers.append((np.sum(np.asarray(temp),axis=0)/len(temp)).tolist())
                
            
    intracluster_d=[]
    for i in range(K):
        M=0
        temp=clusters[i]
        center=centers[i]
        for j in temp:
            M+=np.linalg.norm(np.asarray(j)-np.asarray(center))
        if len(temp)==0:
            M=0
        else:
            M=M/len(temp)
        intracluster_d.append(M)
    return intracluster_d,centers

# %%
def davies_bouldin_index(chromosome):
    intra_distance,centers = intracluster_distances(chromosome)
        
    D = []
    for i in range(K):
        R = []
        for j in range(K):
            if i!=j:
                M = np.linalg.norm(np.asarray(centers[i])-np.asarray(centers[j]))
                r = (intra_distance[i]+intra_distance[j])/M
                R.append(r)
        D.append(max(R))
    return (1/K)*(np.sum(np.asarray(D)))

# %%
def main_func():
    '''
    Steps:
    Repeat 1-5 till 1 chromosome remains in the population
    1.Initialize Population
    2.Compute fitness scores
    3.Selection
    4.Cross-over
    5.Mutation
    '''
    population = population_initialization()
    gen=0
    return_chromosome=[]
    for i in range(100):
        gen+=1
        fitness=fitness_evaluation(population)
        children,fitness = cross_over_function(population,fitness)
        children = mutation(children)
        population=children
        temp = davies_bouldin_index(population[fitness.index(max(fitness))])
        print("Generation: "+str(gen)+" | Purity: "+str(temp))
    return population[fitness.index(max(fitness))]

# %%
def plot(chromosome):
    #Dividing the dataset into clusters
    clusters={}
    for i in range(K):
        clusters[i]=[]
    for i in range(len(chromosome)):
        clusters[chromosome[i]]=X[i]
    
    centers=[]
    for i in range(K):
        temp=clusters[i]
        centers.append((np.sum(np.asarray(temp),axis=0)/len(temp)).tolist())
    
    for i in range(K):
        print(len(clusters[i]))
        
    colors=['r','m','y','k','c']
    fig=plt.figure()
    ax = Axes3D(fig)
    for i in range(K):
        temp=clusters[i]
        for j in temp:
            ax.scatter(j[0], j[1], j[2], c=colors[i], marker='o')
            ax.view_init(330, 60)
    for i in range(K):
        temp=clusters[i]
        ax.scatter(centers[i][0],centers[i][1],centers[i][2],c='b',marker='X')

# %%
chromosome = main_func()
plot(chromosome)
# Out:
# Generation: 1 | Purity: 25.191250380698442
# Generation: 2 | Purity: 31.623145704213414
# Generation: 3 | Purity: 27.98096562716559
# Generation: 4 | Purity: 39.821259187744204
# Generation: 5 | Purity: 124.63321014594699
# Generation: 6 | Purity: 124.63321014594699
# Generation: 7 | Purity: 826.6233549630941
# Generation: 8 | Purity: 826.6233549630941
# Generation: 9 | Purity: 1201.97707844979
# Generation: 10 | Purity: 125.66796546283115
# Generation: 11 | Purity: 65.8891565169192
# Generation: 12 | Purity: 65.8891565169192
# Generation: 13 | Purity: 65.8891565169192
# Generation: 14 | Purity: 65.8891565169192
# Generation: 15 | Purity: 65.8891565169192
# Generation: 16 | Purity: 1247.1549349279471
# Generation: 17 | Purity: 85.58157635985516
# Generation: 18 | Purity: 1253.0397127090216
# Generation: 19 | Purity: 1247.1549349279471
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-5dae36ab3c5d> in <module>
# ----> 1 chromosome = main_func()
#       2 plot(chromosome)
#
# <ipython-input-19-9d3efd3943d7> in main_func()
#      15         gen+=1
#      16         fitness=fitness_evaluation(population)
# ---> 17         children,fitness = cross_over_function(population,fitness)
#      18         children = mutation(children)
#      19         population=children
#
# <ipython-input-15-bf108ac25966> in cross_over_function(population, fitness_scores)
#      17         chromosome2 = population[c2i]
#      18
# ---> 19         c1,c2 = cross_over(chromosome1,chromosome2,fitness_scores[c1i],fitness_scores[c2i])
#      20
#      21         population.append(c1)
#
# <ipython-input-14-2a73d7d01fa6> in cross_over(parent1, parent2, parent1_f_val, parent2_f_val)
#      17             child1.extend(right_parent_2)
#      18             child2.extend(right_parent_1)
# ---> 19             fitness_values = fitness_evaluation([child1,child2])
#      20             temp[fitness_values[0]]=child1
#      21             temp[fitness_values[1]]=child2
#
# <ipython-input-12-2782cfd8b6d7> in fitness_evaluation(population)
#      10     fitness=[]
#      11     for i in population:
# ---> 12         fitness_value = fitness_function(i)
#      13         fitness.append(fitness_value)
#      14     return fitness
#
# <ipython-input-11-7cabbaedc951> in fitness_function(chromosome)
#      29     for i in range(K):
#      30         if(len(clusters[i])!=0):
# ---> 31             U.append(svd.fit_transform(clusters[i]))
#      32
#      33     theta=0
#
# ~\Anaconda3\lib\site-packages\sklearn\decomposition\truncated_svd.py in fit_transform(self, X, y)
#     175             U, Sigma, VT = randomized_svd(X, self.n_components,
#     176                                           n_iter=self.n_iter,
# --> 177                                           random_state=random_state)
#     178         else:
#     179             raise ValueError("unknown algorithm %r" % self.algorithm)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\extmath.py in randomized_svd(M, n_components, n_oversamples, n_iter, power_iteration_normalizer, transpose, flip_sign, random_state)
#     363
#     364     Q = randomized_range_finder(M, n_random, n_iter,
# --> 365                                 power_iteration_normalizer, random_state)
#     366
#     367     # project M to the (k + p) dimensional space using the basis vectors
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\extmath.py in randomized_range_finder(A, size, n_iter, power_iteration_normalizer, random_state)
#     255     # Sample the range of A using by linear projection of Q
#     256     # Extract an orthonormal basis
# --> 257     Q, _ = linalg.qr(safe_sparse_dot(A, Q), mode='economic')
#     258     return Q
#     259
#
# ~\Anaconda3\lib\site-packages\scipy\linalg\decomp_qr.py in qr(a, overwrite_a, lwork, mode, pivoting, check_finite)
#     163     elif mode == 'economic':
#     164         Q, = safecall(gor_un_gqr, "gorgqr/gungqr", qr, tau, lwork=lwork,
# --> 165                       overwrite_a=1)
#     166     else:
#     167         t = qr.dtype.char
#
# ~\Anaconda3\lib\site-packages\scipy\linalg\decomp_qr.py in safecall(f, name, *args, **kwargs)
#      17     if lwork in (None, -1):
#      18         kwargs['lwork'] = -1
# ---> 19         ret = f(*args, **kwargs)
#      20         kwargs['lwork'] = ret[-2][0].real.astype(numpy.int)
#      21     ret = f(*args, **kwargs)
#
# KeyboardInterrupt:
